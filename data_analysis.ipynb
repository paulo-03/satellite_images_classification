# %% [markdown]
# # Data Analysis
#
# This notebook is used to gain insight over the data I work with.
#
# ***Author:*** [Paulo Ribeiro](mailto:paulo.ribeirodecarvalho@epfl.ch)

# %%
from data_analysis import *

data_path = "data/"
categories = ["cloudy", "desert", "green_area", "water"]

# %% [markdown]
# ## Size verification
#
# Check if all images have same size.

# %%
analyze_data(data_path, categories)
# Out:
# Label 'cloudy' has 1500 images with the following size distribution:
#  - Size (256, 256): 1500 images
#
# Label 'desert' has 1131 images with the following size distribution:
#  - Size (256, 256): 1131 images
#
# Label 'green_area' has 1500 images with the following size distribution:
#  - Size (64, 64): 1500 images
#
# Label 'water' has 1500 images with the following size distribution:
#  - Size (64, 64): 1500 images

# %% [markdown]
# ## Satellite Images
#
# Just display few samples to have a better understanding of the data.

# %%
# Choose and intermediate size to not lose too much information of the bigger images, and to create some blurr or unuseful information for the smallest ones.
display_size = (128, 128)

# Display the images
display_sample_images(data_path, categories, display_size)
